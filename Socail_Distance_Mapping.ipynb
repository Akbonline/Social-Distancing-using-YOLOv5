# %% [markdown]
# <a href="https://colab.research.google.com/github/Akbonline/Social-Distancing-using-YOLOv5/blob/main/Socail_Distance_Mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installing YOLOv5:
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.7.0+cu101 CPU

# %%
#Testing to see if YOLO works
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images/
Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='data/images/', update=False, view_img=False, weights=['yolov5s.pt'])
# Using torch 1.7.0+cu101 CPU
#
# ...
# 100% 14.5M/14.5M [00:01<00:00, 7.60MB/s]
#
# Fusing layers...
# Model Summary: 232 layers, 7459581 parameters, 0 gradients
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 buss, 1 skateboards, Done. (0.523s)
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, Done. (0.332s)
# Results saved to runs/detect/exp
# Done. (1.005s)

# %%
# To run the program, use the following syntax:
#     !python detect.py --source ./inference/videofile
# !python detect.py --source ./inference/people2.mp4
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', fourcc='mp4v', img_size=640, iou_thres=0.5, output='inference/output', save_txt=False, source='./inference/people.mp4', view_img=False, weights='weights/yolov5s.pt')
# /content/yolov5/utils/utils.py:574: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:882.)
#   i, j = (x[:, 5:] > conf_thres).nonzero().t()
# video 1/1 (1/341) /content/yolov5/inference/people.mp4: 384x640 29 persons, Done. (0.355s)
# video 1/1 (2/341) /content/yolov5/inference/people.mp4: 384x640 31 persons, Done. (0.352s)
# video 1/1 (3/341) /content/yolov5/inference/people.mp4: 384x640 30 persons, Done. (0.329s)
# video 1/1 (4/341) /content/yolov5/inference/people.mp4: 384x640 31 persons, Done. (0.345s)
# ...
